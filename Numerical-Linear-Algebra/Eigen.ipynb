# %%
import numpy as np
from numpy.linalg import norm, solve, LinAlgError

# %%
def poweriter(A, v0, eps, Nmax=10**3):
    m = A.shape[0]
    assert m == A.shape[1]
    assert m == v0.shape[0]
    
    v = v0 / norm(v0)
    l_o = v0.T @ A @ v0 # old lambda
    for i in range(Nmax):
        print('Lambda {0}: {1}\nv {0}: {2}\n'.format(i, l_o, v))
        v = A @ v
        v /= norm(v)
        l_n = v.T @ A @ v # new lambda
        if abs(l_n - l_o) < eps:
            return l_n, v
        l_o = l_n
    raise StopIteration('Max number of iteration reached')

# %%
def inverseiter(A, v0, mu, eps, Nmax=10**3):
    """The function does not add a check for the initial guess mu.
        It will fail if mu is the exact eigenvalue.
    """
    m = A.shape[0]
    assert m == A.shape[1]
    assert m == v0.shape[0]
    
    v = v0 / norm(v0)
    l_o = mu
    I = np.identity(m)
    for i in range(Nmax):
        print('Lambda {0}: {1}\nv {0}: {2}\n'.format(i, l_o, v))
        v = solve(A - mu * I, v)
        v /= norm(v)
        l_n = v.T @ A @ v # new lambda
        if abs(l_n - l_o) < eps:
            return l_n, v
        l_o = l_n
    raise StopIteration('Max number of iteration reached')

# %%
def rayleigh(A, v0, mu, eps, Nmax=10**3):
    """The function does not add a check for the initial guess mu.
        It will fail if mu is the exact eigenvalue.
    """
    m = A.shape[0]
    assert m == A.shape[1]
    assert m == v0.shape[0]
    
    v = v0 / norm(v0)
    l_o = mu
    I = np.identity(m)
    for i in range(Nmax):
        print('Lambda {0}: {1}\nv {0}: {2}\n'.format(i, l_o, v))
        v = solve(A - l_o * I, v)
        v /= norm(v)
        l_n = v.T @ A @ v # new lambda
        if abs(l_n - l_o) < eps:
            return l_n, v
        l_o = l_n
    raise StopIteration('Max number of iteration reached')

# %%
A = np.array([[2,6,4,-4,-5,10],
              [6,12,-2,9,5,9],
              [4,-2,0,-1,-3,14],
              [-4,9,-1,10,-6,8],
              [-5,5,-3,-6,2,8],
              [10,9,14,8,8,0]], dtype='float64')
v01 = np.array([1, 1, 1, 1, 1, 1], dtype='float64')
v02 = np.array([2, 5, 3, 0, -1, 1], dtype='float64')

# %%
# power iteration with v01 and tolerance 10^-6
l_p1_1, v_p1_1 = poweriter(A, v01, 10**-6)
# Out:
# Lambda 0: 130.0
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 25.093944790739087
# v 1: [0.19396505 0.58189514 0.17904466 0.23872621 0.01492039 0.73109903]
#
# Lambda 2: 26.68892430882623
# v 2: [0.38196112 0.5826348  0.33585333 0.43645215 0.20538925 0.41130245]
#
# Lambda 3: 27.626432593957183
# v 3: [0.24151043 0.60064148 0.17628512 0.34096127 0.03750592 0.65739242]
#
# Lambda 4: 28.191706057991016
# v 4: [0.33988652 0.60523996 0.29487383 0.44005982 0.15774986 0.46116538]
#
# Lambda 5: 28.532635851582512
# v 5: [0.26095672 0.6084737  0.1966518  0.37782654 0.06241541 0.61346625]
#
# Lambda 6: 28.73765203645719
# v 6: [0.31984414 0.6109336  0.27084245 0.43289088 0.13500942 0.49546158]
#
# Lambda 7: 28.86060748894485
# v 7: [0.27359791 0.61150362 0.21221547 0.39404756 0.07857305 0.58713277]
#
# Lambda 8: 28.934206623735413
# v 8: [0.30897857 0.61258148 0.25709221 0.42597969 0.12207069 0.51654605]
#
# Lambda 9: 28.97820583638576
# v 9: [0.28152708 0.61257866 0.22218359 0.40232792 0.08843555 0.57134555]
#
# Lambda 10: 29.00448824313826
# v 10: [0.30270123 0.61306624 0.24907561 0.42114462 0.1144227  0.52917647]
#
# Lambda 11: 29.020179806763288
# v 11: [0.28634537 0.61296436 0.22827015 0.40690275 0.09435553 0.56187271]
#
# Lambda 12: 29.02954534603024
# v 12: [0.29898999 0.61320236 0.24433596 0.41806428 0.10986493 0.53669334]
#
# Lambda 13: 29.035134132716937
# v 13: [0.28923423 0.61311024 0.23192769 0.40953094 0.0978914  0.55619297]
#
# Lambda 14: 29.038468802360168
# v 14: [0.29677891 0.61323473 0.2415158  0.41617109 0.10714443 0.54116287]
#
# Lambda 15: 29.040458368227917
# v 15: [0.29095817 0.61316961 0.23411354 0.4110696  0.10000045 0.55279193]
#
# Lambda 16: 29.041645355200696
# v 16: [0.29545871 0.61323806 0.23983382 0.41502536 0.10552038 0.543822  ]
#
# Lambda 17: 29.0423535013108
# v 17: [0.29198564 0.61319582 0.23541759 0.41197874 0.10125812 0.55075779]
#
# Lambda 18: 29.042775968891
# v 18: [0.29467018 0.61323469 0.23883    0.4143369  0.104551   0.54540531]
#
# Lambda 19: 29.04302800343521
# v 19: [0.29259796 0.61320835 0.23619522 0.41251837 0.10200813 0.54954227]
#
# Lambda 20: 29.043178360716368
# v 20: [0.29419929 0.61323087 0.23823086 0.41392462 0.1039725  0.54634866]
#
# Lambda 21: 29.043268059693673
# v 21: [0.29296295 0.61321476 0.23665894 0.41283942 0.10245544 0.54881637]
#
# Lambda 22: 29.043321571511356
# v 22: [0.29391818 0.61322797 0.23787329 0.41367817 0.1036273  0.54691098]
#
# Lambda 23: 29.04335349507956
# v 23: [0.29318056 0.61321822 0.2369355  0.41303067 0.10272225 0.54838303]
#
# Lambda 24: 29.04337253972372
# v 24: [0.2937504  0.61322601 0.23765992 0.41353098 0.10342133 0.54724627]
#
# Lambda 25: 29.043383901183176
# v 25: [0.29331034 0.61322015 0.23710044 0.41314466 0.1028814  0.54812442]
#
# Lambda 26: 29.0433906790851
# v 26: [0.29365027 0.61322477 0.2375326  0.41344311 0.10329844 0.54744624]
#
# Lambda 27: 29.043394722575115
# v 27: [0.29338774 0.61322126 0.23719883 0.41321263 0.10297634 0.5479701 ]
#
# Lambda 28: 29.043397134798024
# v 28: [0.29359053 0.61322401 0.23745664 0.41339067 0.10322513 0.54756551]
#
# Lambda 29: 29.043398573856592
# v 29: [0.29343391 0.61322191 0.23725752 0.41325317 0.10303297 0.54787802]

# %%
# power iteration with v01 and tolerance 10^-10
l_p1_2, v_p1_2 = poweriter(A, v01, 10**-10)
# Out:
# Lambda 0: 130.0
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 25.093944790739087
# v 1: [0.19396505 0.58189514 0.17904466 0.23872621 0.01492039 0.73109903]
#
# Lambda 2: 26.68892430882623
# v 2: [0.38196112 0.5826348  0.33585333 0.43645215 0.20538925 0.41130245]
#
# Lambda 3: 27.626432593957183
# v 3: [0.24151043 0.60064148 0.17628512 0.34096127 0.03750592 0.65739242]
#
# Lambda 4: 28.191706057991016
# v 4: [0.33988652 0.60523996 0.29487383 0.44005982 0.15774986 0.46116538]
#
# Lambda 5: 28.532635851582512
# v 5: [0.26095672 0.6084737  0.1966518  0.37782654 0.06241541 0.61346625]
#
# Lambda 6: 28.73765203645719
# v 6: [0.31984414 0.6109336  0.27084245 0.43289088 0.13500942 0.49546158]
#
# Lambda 7: 28.86060748894485
# v 7: [0.27359791 0.61150362 0.21221547 0.39404756 0.07857305 0.58713277]
#
# Lambda 8: 28.934206623735413
# v 8: [0.30897857 0.61258148 0.25709221 0.42597969 0.12207069 0.51654605]
#
# Lambda 9: 28.97820583638576
# v 9: [0.28152708 0.61257866 0.22218359 0.40232792 0.08843555 0.57134555]
#
# Lambda 10: 29.00448824313826
# v 10: [0.30270123 0.61306624 0.24907561 0.42114462 0.1144227  0.52917647]
#
# Lambda 11: 29.020179806763288
# v 11: [0.28634537 0.61296436 0.22827015 0.40690275 0.09435553 0.56187271]
#
# Lambda 12: 29.02954534603024
# v 12: [0.29898999 0.61320236 0.24433596 0.41806428 0.10986493 0.53669334]
#
# Lambda 13: 29.035134132716937
# v 13: [0.28923423 0.61311024 0.23192769 0.40953094 0.0978914  0.55619297]
#
# Lambda 14: 29.038468802360168
# v 14: [0.29677891 0.61323473 0.2415158  0.41617109 0.10714443 0.54116287]
#
# Lambda 15: 29.040458368227917
# v 15: [0.29095817 0.61316961 0.23411354 0.4110696  0.10000045 0.55279193]
#
# Lambda 16: 29.041645355200696
# v 16: [0.29545871 0.61323806 0.23983382 0.41502536 0.10552038 0.543822  ]
#
# Lambda 17: 29.0423535013108
# v 17: [0.29198564 0.61319582 0.23541759 0.41197874 0.10125812 0.55075779]
#
# Lambda 18: 29.042775968891
# v 18: [0.29467018 0.61323469 0.23883    0.4143369  0.104551   0.54540531]
#
# Lambda 19: 29.04302800343521
# v 19: [0.29259796 0.61320835 0.23619522 0.41251837 0.10200813 0.54954227]
#
# Lambda 20: 29.043178360716368
# v 20: [0.29419929 0.61323087 0.23823086 0.41392462 0.1039725  0.54634866]
#
# Lambda 21: 29.043268059693673
# v 21: [0.29296295 0.61321476 0.23665894 0.41283942 0.10245544 0.54881637]
#
# Lambda 22: 29.043321571511356
# v 22: [0.29391818 0.61322797 0.23787329 0.41367817 0.1036273  0.54691098]
#
# Lambda 23: 29.04335349507956
# v 23: [0.29318056 0.61321822 0.2369355  0.41303067 0.10272225 0.54838303]
#
# Lambda 24: 29.04337253972372
# v 24: [0.2937504  0.61322601 0.23765992 0.41353098 0.10342133 0.54724627]
#
# Lambda 25: 29.043383901183176
# v 25: [0.29331034 0.61322015 0.23710044 0.41314466 0.1028814  0.54812442]
#
# Lambda 26: 29.0433906790851
# v 26: [0.29365027 0.61322477 0.2375326  0.41344311 0.10329844 0.54744624]
#
# Lambda 27: 29.043394722575115
# v 27: [0.29338774 0.61322126 0.23719883 0.41321263 0.10297634 0.5479701 ]
#
# Lambda 28: 29.043397134798024
# v 28: [0.29359053 0.61322401 0.23745664 0.41339067 0.10322513 0.54756551]
#
# Lambda 29: 29.043398573856592
# v 29: [0.29343391 0.61322191 0.23725752 0.41325317 0.10303297 0.54787802]
#
# Lambda 30: 29.043399432355013
# v 30: [0.29355488 0.61322354 0.23741132 0.41335938 0.10318139 0.54763665]
#
# Lambda 31: 29.04339994450894
# v 31: [0.29346145 0.61322228 0.23729253 0.41327735 0.10306675 0.54782309]
#
# Lambda 32: 29.04340025004432
# v 32: [0.29353362 0.61322326 0.23738428 0.41334071 0.1031553  0.54767909]
#
# Lambda 33: 29.0434004323174
# v 33: [0.29347788 0.61322251 0.23731342 0.41329178 0.10308691 0.54779031]
#
# Lambda 34: 29.043400541055952
# v 34: [0.29352093 0.61322309 0.23736815 0.41332958 0.10313973 0.54770441]
#
# Lambda 35: 29.04340060592606
# v 35: [0.29348768 0.61322264 0.23732588 0.41330038 0.10309893 0.54777076]
#
# Lambda 36: 29.04340064462557
# v 36: [0.29351336 0.61322299 0.23735853 0.41332293 0.10313045 0.54771951]
#
# Lambda 37: 29.043400667712525
# v 37: [0.29349352 0.61322272 0.23733331 0.41330552 0.10310611 0.5477591 ]
#
# Lambda 38: 29.04340068148549
# v 38: [0.29350884 0.61322293 0.23735279 0.41331897 0.10312491 0.54772852]
#
# Lambda 39: 29.043400689702025
# v 39: [0.29349701 0.61322277 0.23733774 0.41330858 0.10311039 0.54775214]
#
# Lambda 40: 29.043400694603754
# v 40: [0.29350615 0.61322289 0.23734936 0.4133166  0.1031216  0.5477339 ]
#
# Lambda 41: 29.043400697527986
# v 41: [0.29349909 0.6132228  0.23734039 0.4133104  0.10311294 0.54774799]
#
# Lambda 42: 29.043400699272482
# v 42: [0.29350454 0.61322287 0.23734732 0.41331519 0.10311963 0.54773711]
#
# Lambda 43: 29.0434007003132
# v 43: [0.29350033 0.61322281 0.23734197 0.41331149 0.10311446 0.54774551]
#
# Lambda 44: 29.04340070093405
# v 44: [0.29350359 0.61322286 0.2373461  0.41331435 0.10311845 0.54773902]
#
# Lambda 45: 29.04340070130445
# v 45: [0.29350107 0.61322282 0.23734291 0.41331214 0.10311537 0.54774403]
#
# Lambda 46: 29.043400701525407
# v 46: [0.29350301 0.61322285 0.23734538 0.41331385 0.10311775 0.54774016]
#
# Lambda 47: 29.04340070165722
# v 47: [0.29350151 0.61322283 0.23734347 0.41331253 0.10311591 0.54774315]

# %% [markdown]
# ### 18 more iterations for a lower tolerance

# %%
# power iteration with v02 and tolerance 10^-6
l_p2_1, v_p2_1 = poweriter(A, v02, 10**-6)
# Out:
# Lambda 0: 604.0
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 26.298838587342964
# v 1: [0.41999108 0.48195698 0.1032765  0.33048479 0.0826212  0.68162487]
#
# Lambda 2: 28.214385800638166
# v 2: [0.32699814 0.62446884 0.34310402 0.38336872 0.12884703 0.47097493]
#
# Lambda 3: 28.64118779053343
# v 3: [0.2875921  0.59222814 0.20370755 0.37389339 0.07560341 0.61607443]
#
# Lambda 4: 28.814984567706173
# v 4: [0.31845284 0.61108348 0.27566305 0.42055017 0.12932295 0.50555689]
#
# Lambda 5: 28.908797518491042
# v 5: [0.28029731 0.60913328 0.21785052 0.39373827 0.08326618 0.58392477]
#
# Lambda 6: 28.96337467412309
# v 6: [0.30780302 0.61221134 0.2561132  0.42209397 0.11940836 0.52195684]
#
# Lambda 7: 28.995707221246185
# v 7: [0.28406117 0.61219703 0.22504064 0.40306731 0.09077616 0.56848675]
#
# Lambda 8: 29.014955659995998
# v 8: [0.30168065 0.61294008 0.24778856 0.41953382 0.11283858 0.53212113]
#
# Lambda 9: 29.026431833219874
# v 9: [0.28756868 0.61290565 0.22976767 0.40761578 0.09567355 0.55995865]
#
# Lambda 10: 29.033277313348528
# v 10: [0.29827685 0.61316744 0.24341911 0.41726177 0.10890302 0.53836465]
#
# Lambda 11: 29.037361180932635
# v 11: [0.28989902 0.61310629 0.23276114 0.4100267  0.09866138 0.55500047]
#
# Lambda 12: 29.039797602442654
# v 12: [0.29632463 0.61322434 0.24093407 0.41572913 0.1065644  0.54213624]
#
# Lambda 13: 29.041251158139843
# v 13: [0.29133899 0.61317315 0.23459481 0.41138261 0.10045592 0.55206748]
#
# Lambda 14: 29.042118332105154
# v 14: [0.29518007 0.61323406 0.23947824 0.41477028 0.10517254 0.5443962 ]
#
# Lambda 15: 29.042635672534203
# v 15: [0.29220884 0.61319897 0.23570055 0.41216955 0.10152885 0.55032211]
#
# Lambda 16: 29.042944306242983
# v 16: [0.29450194 0.61323267 0.23861571 0.4141867  0.10434299 0.54574606]
#
# Lambda 17: 29.043128429263604
# v 17: [0.29273007 0.61321035 0.23636295 0.41263313 0.10216937 0.54928139]
#
# Lambda 18: 29.04323827201383
# v 18: [0.2940984  0.61322968 0.23810246 0.41383545 0.10384827 0.54655143]
#
# Lambda 19: 29.043303801054297
# v 19: [0.29304149 0.61321594 0.23675872 0.41290809 0.10255156 0.54866045]
#
# Lambda 20: 29.04334289375417
# v 20: [0.29385784 0.61322723 0.23779654 0.41362506 0.10355315 0.5470318 ]
#
# Lambda 21: 29.043366215291943
# v 21: [0.29322734 0.6132189  0.23699494 0.41307167 0.10277957 0.54828994]
#
# Lambda 22: 29.04338012821864
# v 22: [0.29371436 0.61322556 0.23761409 0.41349931 0.10337708 0.5473183 ]
#
# Lambda 23: 29.04338842824911
# v 23: [0.29333822 0.61322055 0.23713589 0.41316913 0.10291559 0.54806886]
#
# Lambda 24: 29.043393379794924
# v 24: [0.29362876 0.6132245  0.23750525 0.41342422 0.10327204 0.5474892 ]
#
# Lambda 25: 29.043396333736297
# v 25: [0.29340437 0.61322149 0.23721997 0.41322723 0.10299673 0.54793694]
#
# Lambda 26: 29.043398095967618
# v 26: [0.29357769 0.61322384 0.23744032 0.4133794  0.10320938 0.54759113]
#
# Lambda 27: 29.043399147261045
# v 27: [0.29344382 0.61322204 0.23727013 0.41326188 0.10304514 0.54785824]

# %%
# power iteration with v02 and tolerance 10^-10
l_p2_2, v_p2_2 = poweriter(A, v02, 10**-10)
# Out:
# Lambda 0: 604.0
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 26.298838587342964
# v 1: [0.41999108 0.48195698 0.1032765  0.33048479 0.0826212  0.68162487]
#
# Lambda 2: 28.214385800638166
# v 2: [0.32699814 0.62446884 0.34310402 0.38336872 0.12884703 0.47097493]
#
# Lambda 3: 28.64118779053343
# v 3: [0.2875921  0.59222814 0.20370755 0.37389339 0.07560341 0.61607443]
#
# Lambda 4: 28.814984567706173
# v 4: [0.31845284 0.61108348 0.27566305 0.42055017 0.12932295 0.50555689]
#
# Lambda 5: 28.908797518491042
# v 5: [0.28029731 0.60913328 0.21785052 0.39373827 0.08326618 0.58392477]
#
# Lambda 6: 28.96337467412309
# v 6: [0.30780302 0.61221134 0.2561132  0.42209397 0.11940836 0.52195684]
#
# Lambda 7: 28.995707221246185
# v 7: [0.28406117 0.61219703 0.22504064 0.40306731 0.09077616 0.56848675]
#
# Lambda 8: 29.014955659995998
# v 8: [0.30168065 0.61294008 0.24778856 0.41953382 0.11283858 0.53212113]
#
# Lambda 9: 29.026431833219874
# v 9: [0.28756868 0.61290565 0.22976767 0.40761578 0.09567355 0.55995865]
#
# Lambda 10: 29.033277313348528
# v 10: [0.29827685 0.61316744 0.24341911 0.41726177 0.10890302 0.53836465]
#
# Lambda 11: 29.037361180932635
# v 11: [0.28989902 0.61310629 0.23276114 0.4100267  0.09866138 0.55500047]
#
# Lambda 12: 29.039797602442654
# v 12: [0.29632463 0.61322434 0.24093407 0.41572913 0.1065644  0.54213624]
#
# Lambda 13: 29.041251158139843
# v 13: [0.29133899 0.61317315 0.23459481 0.41138261 0.10045592 0.55206748]
#
# Lambda 14: 29.042118332105154
# v 14: [0.29518007 0.61323406 0.23947824 0.41477028 0.10517254 0.5443962 ]
#
# Lambda 15: 29.042635672534203
# v 15: [0.29220884 0.61319897 0.23570055 0.41216955 0.10152885 0.55032211]
#
# Lambda 16: 29.042944306242983
# v 16: [0.29450194 0.61323267 0.23861571 0.4141867  0.10434299 0.54574606]
#
# Lambda 17: 29.043128429263604
# v 17: [0.29273007 0.61321035 0.23636295 0.41263313 0.10216937 0.54928139]
#
# Lambda 18: 29.04323827201383
# v 18: [0.2940984  0.61322968 0.23810246 0.41383545 0.10384827 0.54655143]
#
# Lambda 19: 29.043303801054297
# v 19: [0.29304149 0.61321594 0.23675872 0.41290809 0.10255156 0.54866045]
#
# Lambda 20: 29.04334289375417
# v 20: [0.29385784 0.61322723 0.23779654 0.41362506 0.10355315 0.5470318 ]
#
# Lambda 21: 29.043366215291943
# v 21: [0.29322734 0.6132189  0.23699494 0.41307167 0.10277957 0.54828994]
#
# Lambda 22: 29.04338012821864
# v 22: [0.29371436 0.61322556 0.23761409 0.41349931 0.10337708 0.5473183 ]
#
# Lambda 23: 29.04338842824911
# v 23: [0.29333822 0.61322055 0.23713589 0.41316913 0.10291559 0.54806886]
#
# Lambda 24: 29.043393379794924
# v 24: [0.29362876 0.6132245  0.23750525 0.41342422 0.10327204 0.5474892 ]
#
# Lambda 25: 29.043396333736297
# v 25: [0.29340437 0.61322149 0.23721997 0.41322723 0.10299673 0.54793694]
#
# Lambda 26: 29.043398095967618
# v 26: [0.29357769 0.61322384 0.23744032 0.4133794  0.10320938 0.54759113]
#
# Lambda 27: 29.043399147261045
# v 27: [0.29344382 0.61322204 0.23727013 0.41326188 0.10304514 0.54785824]
#
# Lambda 28: 29.04339977443059
# v 28: [0.29354722 0.61322344 0.23740158 0.41335266 0.103172   0.54765194]
#
# Lambda 29: 29.04340014858078
# v 29: [0.29346736 0.61322237 0.23730005 0.41328255 0.10307401 0.54781129]
#
# Lambda 30: 29.043400371787357
# v 30: [0.29352905 0.6132232  0.23737847 0.4133367  0.10314969 0.54768821]
#
# Lambda 31: 29.043400504945584
# v 31: [0.2934814  0.61322256 0.2373179  0.41329488 0.10309124 0.54778327]
#
# Lambda 32: 29.043400584383704
# v 32: [0.2935182  0.61322305 0.23736469 0.41332718 0.10313639 0.54770985]
#
# Lambda 33: 29.043400631774063
# v 33: [0.29348978 0.61322267 0.23732855 0.41330223 0.10310152 0.54776656]
#
# Lambda 34: 29.043400660045712
# v 34: [0.29351173 0.61322297 0.23735646 0.4133215  0.10312845 0.54772276]
#
# Lambda 35: 29.043400676911705
# v 35: [0.29349478 0.61322274 0.23733491 0.41330662 0.10310765 0.54775659]
#
# Lambda 36: 29.043400686973442
# v 36: [0.29350787 0.61322291 0.23735156 0.41331812 0.10312372 0.54773046]
#
# Lambda 37: 29.043400692975958
# v 37: [0.29349776 0.61322278 0.2373387  0.41330923 0.10311131 0.54775064]
#
# Lambda 38: 29.043400696556887
# v 38: [0.29350557 0.61322288 0.23734863 0.41331609 0.10312089 0.54773505]
#
# Lambda 39: 29.043400698693162
# v 39: [0.29349954 0.6132228  0.23734096 0.4133108  0.10311349 0.5477471 ]
#
# Lambda 40: 29.043400699967584
# v 40: [0.2935042  0.61322287 0.23734688 0.41331489 0.10311921 0.5477378 ]
#
# Lambda 41: 29.04340070072788
# v 41: [0.2935006  0.61322282 0.23734231 0.41331173 0.10311479 0.54774498]
#
# Lambda 42: 29.043400701181444
# v 42: [0.29350338 0.61322285 0.23734584 0.41331417 0.1031182  0.54773943]
#
# Lambda 43: 29.043400701452022
# v 43: [0.29350123 0.61322283 0.23734311 0.41331228 0.10311557 0.54774372]
#
# Lambda 44: 29.04340070161345
# v 44: [0.29350289 0.61322285 0.23734522 0.41331374 0.1031176  0.54774041]

# %% [markdown]
# ### 17 more iterations for a lower tolerance

# %%
# inverse iteration with v01, mu = 10 and tolerance 10^-6
l_i111, v_i111 = inverseiter(A, v01, 10, 10**-6)
# Out:
# Lambda 0: 10
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 11.034259967369438
# v 1: [ 0.03191823  0.50873179 -0.23792092 -0.48463665  0.65840819  0.12325905]
#
# Lambda 2: 10.321965425824418
# v 2: [-0.14131754  0.38733009 -0.32991764 -0.43221658  0.73071903 -0.01994073]
#
# Lambda 3: 10.321298060011843
# v 3: [-0.1442638   0.39126247 -0.33876583 -0.4281937   0.72611113 -0.02742506]
#
# Lambda 4: 10.321295051628622
# v 4: [-0.14484663  0.39132626 -0.33908504 -0.42758174  0.72616478 -0.02762448]

# %%
# inverse iteration with v01, mu = 10 and tolerance 10^-10
l_i112, v_i112 = inverseiter(A, v01, 10, 10**-10)
# Out:
# Lambda 0: 10
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 11.034259967369438
# v 1: [ 0.03191823  0.50873179 -0.23792092 -0.48463665  0.65840819  0.12325905]
#
# Lambda 2: 10.321965425824418
# v 2: [-0.14131754  0.38733009 -0.32991764 -0.43221658  0.73071903 -0.01994073]
#
# Lambda 3: 10.321298060011843
# v 3: [-0.1442638   0.39126247 -0.33876583 -0.4281937   0.72611113 -0.02742506]
#
# Lambda 4: 10.321295051628622
# v 4: [-0.14484663  0.39132626 -0.33908504 -0.42758174  0.72616478 -0.02762448]
#
# Lambda 5: 10.321295034545377
# v 5: [-0.1448645   0.39134953 -0.33912169 -0.42754746  0.72615077 -0.0276501 ]

# %% [markdown]
# ### 1 more iterations for a lower tolerance

# %%
# inverse iteration with v01, mu = 40 and tolerance 10^-6
l_i121, v_i121 = inverseiter(A, v01, 40, 10**-6)
# Out:
# Lambda 0: 40
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 28.60563469213931
# v 1: [-0.32826052 -0.56063716 -0.29658237 -0.38718235 -0.19151258 -0.55080184]
#
# Lambda 2: 29.006506507152828
# v 2: [0.30499376 0.59713535 0.25811181 0.39526103 0.12866895 0.55767329]
#
# Lambda 3: 29.038590932193912
# v 3: [-0.29817896 -0.60773786 -0.24532851 -0.40412298 -0.11112101 -0.55307745]
#
# Lambda 4: 29.04263280073497
# v 4: [0.29560146 0.61120483 0.24058616 0.40907799 0.10579949 0.55011671]
#
# Lambda 5: 29.043268547863885
# v 5: [-0.29446503 -0.61243735 -0.23869703 -0.41143941 -0.10406151 -0.5487471 ]
#
# Lambda 6: 29.04337724889117
# v 6: [0.29394106 0.61290474 0.23791654 0.41249951 0.10346145 0.54816241]
#
# Lambda 7: 29.04339647817395
# v 7: [-0.29369976 -0.61309058 -0.23758816 -0.41296305 -0.10324582 -0.54791795]
#
# Lambda 8: 29.04339993525744
# v 8: [0.29359009 0.61316692 0.23744866 0.41316318 0.10316604 0.54781591]

# %%
# inverse iteration with v01, mu = 40 and tolerance 10^-10
l_i122, v_i122 = inverseiter(A, v01, 40, 10**-10)
# Out:
# Lambda 0: 40
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 28.60563469213931
# v 1: [-0.32826052 -0.56063716 -0.29658237 -0.38718235 -0.19151258 -0.55080184]
#
# Lambda 2: 29.006506507152828
# v 2: [0.30499376 0.59713535 0.25811181 0.39526103 0.12866895 0.55767329]
#
# Lambda 3: 29.038590932193912
# v 3: [-0.29817896 -0.60773786 -0.24532851 -0.40412298 -0.11112101 -0.55307745]
#
# Lambda 4: 29.04263280073497
# v 4: [0.29560146 0.61120483 0.24058616 0.40907799 0.10579949 0.55011671]
#
# Lambda 5: 29.043268547863885
# v 5: [-0.29446503 -0.61243735 -0.23869703 -0.41143941 -0.10406151 -0.5487471 ]
#
# Lambda 6: 29.04337724889117
# v 6: [0.29394106 0.61290474 0.23791654 0.41249951 0.10346145 0.54816241]
#
# Lambda 7: 29.04339647817395
# v 7: [-0.29369976 -0.61309058 -0.23758816 -0.41296305 -0.10324582 -0.54791795]
#
# Lambda 8: 29.04339993525744
# v 8: [0.29359009 0.61316692 0.23744866 0.41316318 0.10316604 0.54781591]
#
# Lambda 9: 29.043400562101493
# v 9: [-0.29354092 -0.61319896 -0.23738908 -0.41324904 -0.10313586 -0.54777314]
#
# Lambda 10: 29.04340067630885
# v 10: [0.29351913 0.61321258 0.23736354 0.41328576 0.10312425 0.54775512]
#
# Lambda 11: 29.04340069717584
# v 11: [-0.29350955 -0.61321842 -0.23735257 -0.41330144 -0.10311971 -0.5477475 ]
#
# Lambda 12: 29.04340070099515
# v 12: [0.29350537 0.61322093 0.23734786 0.41330813 0.10311792 0.54774426]
#
# Lambda 13: 29.043400701694985
# v 13: [-0.29350355 -0.61322201 -0.23734583 -0.41331098 -0.1031172  -0.54774288]
#
# Lambda 14: 29.04340070182332
# v 14: [0.29350276 0.61322248 0.23734496 0.4133122  0.10311691 0.54774229]

# %% [markdown]
# ### 6 more iterations for a lower tolerance

# %%
# inverse iteration with v02, mu = 10 and tolerance 10^-6
l_i211, v_i211 = inverseiter(A, v02, 10, 10**-6)
# Out:
# Lambda 0: 10
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 10.599509993109319
# v 1: [ 0.15803588 -0.42459327  0.52225504  0.34120865  0.01944122  0.63654817]
#
# Lambda 2: 10.316447887425824
# v 2: [ 0.2036607  -0.37111469  0.35427759  0.37644796 -0.7433075   0.0326264 ]
#
# Lambda 3: 10.321315070368604
# v 3: [ 0.14515034 -0.3936324   0.34223976  0.42576966 -0.72434149  0.03010742]
#
# Lambda 4: 10.321295283527753
# v 4: [ 0.14509347 -0.39137031  0.33922257  0.42730746 -0.72618604  0.02770157]

# %%
# inverse iteration with v02, mu = 10 and tolerance 10^-10
l_i212, v_i212 = inverseiter(A, v02, 10, 10**-10)
# Out:
# Lambda 0: 10
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 10.599509993109319
# v 1: [ 0.15803588 -0.42459327  0.52225504  0.34120865  0.01944122  0.63654817]
#
# Lambda 2: 10.316447887425824
# v 2: [ 0.2036607  -0.37111469  0.35427759  0.37644796 -0.7433075   0.0326264 ]
#
# Lambda 3: 10.321315070368604
# v 3: [ 0.14515034 -0.3936324   0.34223976  0.42576966 -0.72434149  0.03010742]
#
# Lambda 4: 10.321295283527753
# v 4: [ 0.14509347 -0.39137031  0.33922257  0.42730746 -0.72618604  0.02770157]
#
# Lambda 5: 10.321295036149527
# v 5: [ 0.14487243 -0.3913598   0.33913756  0.42753218 -0.72614482  0.02766104]
#
# Lambda 6: 10.321295034460974
# v 6: [ 0.1448681  -0.39135079  0.33912442  0.42754303 -0.72615064  0.02765175]

# %% [markdown]
# ### 2 more iterations for a lower tolerance

# %%
# inverse iteration with v02, mu = 40 and tolerance 10^-6
l_i221, v_i221 = inverseiter(A, v02, 10, 10**-6)
# Out:
# Lambda 0: 10
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 10.599509993109319
# v 1: [ 0.15803588 -0.42459327  0.52225504  0.34120865  0.01944122  0.63654817]
#
# Lambda 2: 10.316447887425824
# v 2: [ 0.2036607  -0.37111469  0.35427759  0.37644796 -0.7433075   0.0326264 ]
#
# Lambda 3: 10.321315070368604
# v 3: [ 0.14515034 -0.3936324   0.34223976  0.42576966 -0.72434149  0.03010742]
#
# Lambda 4: 10.321295283527753
# v 4: [ 0.14509347 -0.39137031  0.33922257  0.42730746 -0.72618604  0.02770157]

# %%
# inverse iteration with v02, mu = 40 and tolerance 10^-10
l_i222, v_i222 = inverseiter(A, v02, 40, 10**-10)
# Out:
# Lambda 0: 40
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 27.609805494781202
# v 1: [-0.3528116  -0.69007496 -0.32371574 -0.27117643 -0.0164817  -0.46980883]
#
# Lambda 2: 28.927493676833137
# v 2: [0.32363734 0.63092775 0.26408223 0.36572736 0.07955713 0.53606323]
#
# Lambda 3: 29.031747091438106
# v 3: [-0.30631741 -0.61599424 -0.24670281 -0.39615024 -0.09692799 -0.54729189]
#
# Lambda 4: 29.04191262616834
# v 4: [0.298713   0.61312173 0.24103474 0.40677541 0.10156415 0.54861009]
#
# Lambda 5: 29.043175712040885
# v 5: [-0.29559771 -0.61283999 -0.23890057 -0.41072523 -0.102764   -0.54837944]
#
# Lambda 6: 29.043363244807985
# v 6: [0.29434677 0.6129684  0.23801907 0.41226108 0.10305562 0.54808482]
#
# Lambda 7: 29.043394148911037
# v 7: [-0.29384524 -0.61308938 -0.23763914 -0.41287766 -0.10311685 -0.54790782]
#
# Lambda 8: 29.043399526859602
# v 8: [0.29364285 0.61315895 0.23747306 0.4131307  0.10312457 0.54781829]
#
# Lambda 9: 29.043400488590745
# v 9: [-0.29356039 -0.6131936  -0.23740035 -0.41323609 -0.10312242 -0.54777612]
#
# Lambda 10: 29.043400662911658
# v 10: [0.29352646 0.61320979 0.23736861 0.41328041 0.10311987 0.54775698]
#
# Lambda 11: 29.04340069472051
# v 11: [-0.29351237 -0.6132171  -0.23735481 -0.41329918 -0.10311829 -0.54774846]
#
# Lambda 12: 29.043400700544098
# v 12: [0.29350648 0.61322034 0.23734883 0.41330716 0.10311746 0.54774472]
#
# Lambda 13: 29.043400701612043
# v 13: [-0.29350399 -0.61322175 -0.23734625 -0.41331056 -0.10311705 -0.54774309]
#
# Lambda 14: 29.04340070180806
# v 14: [0.29350294 0.61322237 0.23734514 0.41331202 0.10311687 0.54774238]

# %% [markdown]
# ### 10 more iterations for a lower tolerance

# %%
# Rayleigh quotient iteration with v01, mu = 10 and tolerance 10^-6
l_r111, v_r111 = rayleigh(A, v01, 10, 10**-6)
# Out:
# Lambda 0: 10
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 11.034259967369438
# v 1: [ 0.03191823  0.50873179 -0.23792092 -0.48463665  0.65840819  0.12325905]
#
# Lambda 2: 10.327400178566965
# v 2: [ 0.15760338 -0.4011504   0.3628408   0.41092895 -0.71519675  0.047086  ]
#
# Lambda 3: 10.321295046508185
# v 3: [-0.14483604  0.39134158 -0.33909999 -0.42758089  0.72615172 -0.02763591]

# %%
# Rayleigh quotient iteration with v01, mu = 10 and tolerance 10^-10
l_r112, v_r112 = rayleigh(A, v01, 10, 10**-10)
# Out:
# Lambda 0: 10
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 11.034259967369438
# v 1: [ 0.03191823  0.50873179 -0.23792092 -0.48463665  0.65840819  0.12325905]
#
# Lambda 2: 10.327400178566965
# v 2: [ 0.15760338 -0.4011504   0.3628408   0.41092895 -0.71519675  0.047086  ]
#
# Lambda 3: 10.321295046508185
# v 3: [-0.14483604  0.39134158 -0.33909999 -0.42758089  0.72615172 -0.02763591]
#
# Lambda 4: 10.321295034451008
# v 4: [ 0.14486714 -0.39135051  0.33912377  0.42754417 -0.72615063  0.02765137]

# %% [markdown]
# ### 1 more iterations for a lower tolerance

# %%
# Rayleigh quotient iteration with v01, mu = 40 and tolerance 10^-6
l_r121, v_r121 = rayleigh(A, v01, 40, 10**-6)
# Out:
# Lambda 0: 40
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 28.60563469213931
# v 1: [-0.32826052 -0.56063716 -0.29658237 -0.38718235 -0.19151258 -0.55080184]
#
# Lambda 2: 29.043246030820214
# v 2: [-0.29266136 -0.61421252 -0.23592114 -0.41473226 -0.10157208 -0.54691297]
#
# Lambda 3: 29.043400701852136
# v 3: [-0.29350218 -0.61322283 -0.23734431 -0.41331309 -0.10311672 -0.54774186]

# %%
# Rayleigh quotient iteration with v01, mu = 40 and tolerance 10^-10
l_r122, v_r122 = rayleigh(A, v01, 40, 10**-10)
# Out:
# Lambda 0: 40
# v 0: [0.40824829 0.40824829 0.40824829 0.40824829 0.40824829 0.40824829]
#
# Lambda 1: 28.60563469213931
# v 1: [-0.32826052 -0.56063716 -0.29658237 -0.38718235 -0.19151258 -0.55080184]
#
# Lambda 2: 29.043246030820214
# v 2: [-0.29266136 -0.61421252 -0.23592114 -0.41473226 -0.10157208 -0.54691297]
#
# Lambda 3: 29.043400701852136
# v 3: [-0.29350218 -0.61322283 -0.23734431 -0.41331309 -0.10311672 -0.54774186]

# %% [markdown]
# ### 0 more iterations for a lower tolerance

# %%
# Rayleigh quotient iteration with v02, mu = 10 and tolerance 10^-6
l_r211, v_r211 = rayleigh(A, v02, 10, 10**-6)
# Out:
# Lambda 0: 10
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 10.599509993109319
# v 1: [ 0.15803588 -0.42459327  0.52225504  0.34120865  0.01944122  0.63654817]
#
# Lambda 2: 10.324225797013346
# v 2: [-0.09188575  0.40276523 -0.31857418 -0.47292621  0.7098078  -0.01900924]
#
# Lambda 3: 10.321295039255949
# v 3: [ 0.14487491 -0.39136953  0.33915144  0.42752409 -0.72613693  0.02767245]

# %%
# Rayleigh quotient iteration with v02, mu = 10 and tolerance 10^-10
l_r212, v_r212 = rayleigh(A, v02, 10, 10**-10)
# Out:
# Lambda 0: 10
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 10.599509993109319
# v 1: [ 0.15803588 -0.42459327  0.52225504  0.34120865  0.01944122  0.63654817]
#
# Lambda 2: 10.324225797013346
# v 2: [-0.09188575  0.40276523 -0.31857418 -0.47292621  0.7098078  -0.01900924]
#
# Lambda 3: 10.321295039255949
# v 3: [ 0.14487491 -0.39136953  0.33915144  0.42752409 -0.72613693  0.02767245]
#
# Lambda 4: 10.321295034451014
# v 4: [-0.14486714  0.39135051 -0.33912377 -0.42754417  0.72615063 -0.02765137]

# %% [markdown]
# ### 1 more iterations for a lower tolerance

# %%
# Rayleigh quotient iteration with v02, mu = 40 and tolerance 10^-6
l_r221, v_r221 = rayleigh(A, v02, 40, 10**-6)
# Out:
# Lambda 0: 40
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 27.609805494781202
# v 1: [-0.3528116  -0.69007496 -0.32371574 -0.27117643 -0.0164817  -0.46980883]
#
# Lambda 2: 29.03842533148632
# v 2: [-0.28590451 -0.61040106 -0.23113931 -0.42390046 -0.10740493 -0.54864958]
#
# Lambda 3: 29.043400701537806
# v 3: [-0.29350454 -0.61322273 -0.23734609 -0.41331008 -0.10311608 -0.54774232]

# %%
# Rayleigh quotient iteration with v02, mu = 40 and tolerance 10^-10
l_r222, v_r222 = rayleigh(A, v02, 40, 10**-10)
# Out:
# Lambda 0: 40
# v 0: [ 0.31622777  0.79056942  0.47434165  0.         -0.15811388  0.15811388]
#
# Lambda 1: 27.609805494781202
# v 1: [-0.3528116  -0.69007496 -0.32371574 -0.27117643 -0.0164817  -0.46980883]
#
# Lambda 2: 29.03842533148632
# v 2: [-0.28590451 -0.61040106 -0.23113931 -0.42390046 -0.10740493 -0.54864958]
#
# Lambda 3: 29.043400701537806
# v 3: [-0.29350454 -0.61322273 -0.23734609 -0.41331008 -0.10311608 -0.54774232]
#
# Lambda 4: 29.043400701852146
# v 4: [-0.29350217 -0.61322284 -0.2373443  -0.41331311 -0.10311671 -0.54774185]

# %% [markdown]
# ### 1 more iterations for a lower tolerance

# %%
names = ['p(1, ,1)', 'p(1, ,2)', 'p(2, ,1)', 'p(2, ,2)', 
         'i(1,1,1)', 'i(1,1,2)', 'i(1,2,1)', 'i(1,2,2)', 
         'i(2,1,1)', 'i(2,1,2)', 'i(2,2,1)', 'i(2,2,2)', 
         'r(1,1,1)', 'r(1,1,2)', 'r(1,2,1)', 'r(1,2,2)', 
         'r(2,1,1)', 'r(2,1,2)', 'r(2,2,1)', 'r(2,2,2)']

# %%
lams = [l_p1_1, l_p1_2, l_p2_1, l_p2_2, 
        l_i111, l_i112, l_i121, l_i122, 
        l_i211, l_i212, l_i221, l_i222, 
        l_r111, l_r112, l_r121, l_r122, 
        l_r211, l_r212, l_r221, l_r222]

# %%
vecs = [v_p1_1, v_p1_2, v_p2_1, v_p2_2, 
        v_i111, v_i112, v_i121, v_i122, 
        v_i211, v_i212, v_i221, v_i222, 
        v_r111, v_r112, v_r121, v_r122, 
        v_r211, v_r212, v_r221, v_r222]

# %% [markdown]
# ### Notation: (initial vector number, initial mu, tolerance)
# 1 means v01, mu = 10, or tolerance = 10^-6, respectively
#
# 2 means v02, mu = 40, or tolerance = 10^-10, respectively

# %%
for n, l in zip(names, lams):
    print('{} eigenvalue: {}'.format(n, l))
# Out:
# p(1, ,1) eigenvalue: 29.043399432355013
# p(1, ,2) eigenvalue: 29.043400701735862
# p(2, ,1) eigenvalue: 29.04339977443059
# p(2, ,2) eigenvalue: 29.043400701709754
# i(1,1,1) eigenvalue: 10.321295034545377
# i(1,1,2) eigenvalue: 10.32129503445152
# i(1,2,1) eigenvalue: 29.043400562101493
# i(1,2,2) eigenvalue: 29.04340070184686
# i(2,1,1) eigenvalue: 10.321295036149527
# i(2,1,2) eigenvalue: 10.321295034451065
# i(2,2,1) eigenvalue: 10.321295036149527
# i(2,2,2) eigenvalue: 29.043400701844057
# r(1,1,1) eigenvalue: 10.321295034451008
# r(1,1,2) eigenvalue: 10.32129503445101
# r(1,2,1) eigenvalue: 29.043400701852143
# r(1,2,2) eigenvalue: 29.043400701852143
# r(2,1,1) eigenvalue: 10.321295034451014
# r(2,1,2) eigenvalue: 10.321295034451012
# r(2,2,1) eigenvalue: 29.043400701852146
# r(2,2,2) eigenvalue: 29.043400701852146

# %%
for n, v in zip(names, vecs):
    print('{} eigenvector: \n{}'.format(n, v[:, None]))
# Out:
# p(1, ,1) eigenvector:
# [[0.29355488]
#  [0.61322354]
#  [0.23741132]
#  [0.41335938]
#  [0.10318139]
#  [0.54763665]]
# p(1, ,2) eigenvector:
# [[0.29350267]
#  [0.61322284]
#  [0.23734494]
#  [0.41331355]
#  [0.10311733]
#  [0.54774084]]
# p(2, ,1) eigenvector:
# [[0.29354722]
#  [0.61322344]
#  [0.23740158]
#  [0.41335266]
#  [0.103172  ]
#  [0.54765194]]
# p(2, ,2) eigenvector:
# [[0.29350161]
#  [0.61322283]
#  [0.23734359]
#  [0.41331261]
#  [0.10311603]
#  [0.54774296]]
# i(1,1,1) eigenvector:
# [[-0.1448645 ]
#  [ 0.39134953]
#  [-0.33912169]
#  [-0.42754746]
#  [ 0.72615077]
#  [-0.0276501 ]]
# i(1,1,2) eigenvector:
# [[-0.14486701]
#  [ 0.3913504 ]
#  [-0.33912359]
#  [-0.42754438]
#  [ 0.72615069]
#  [-0.02765125]]
# i(1,2,1) eigenvector:
# [[-0.29354092]
#  [-0.61319896]
#  [-0.23738908]
#  [-0.41324904]
#  [-0.10313586]
#  [-0.54777314]]
# i(1,2,2) eigenvector:
# [[-0.29350242]
#  [-0.61322268]
#  [-0.23734458]
#  [-0.41331272]
#  [-0.1031168 ]
#  [-0.54774204]]
# i(2,1,1) eigenvector:
# [[ 0.14487243]
#  [-0.3913598 ]
#  [ 0.33913756]
#  [ 0.42753218]
#  [-0.72614482]
#  [ 0.02766104]]
# i(2,1,2) eigenvector:
# [[ 0.14486718]
#  [-0.39135055]
#  [ 0.33912384]
#  [ 0.4275441 ]
#  [-0.72615061]
#  [ 0.02765142]]
# i(2,2,1) eigenvector:
# [[ 0.14487243]
#  [-0.3913598 ]
#  [ 0.33913756]
#  [ 0.42753218]
#  [-0.72614482]
#  [ 0.02766104]]
# i(2,2,2) eigenvector:
# [[-0.2935025 ]
#  [-0.61322264]
#  [-0.23734466]
#  [-0.41331264]
#  [-0.10311678]
#  [-0.54774208]]
# r(1,1,1) eigenvector:
# [[ 0.14486714]
#  [-0.39135051]
#  [ 0.33912377]
#  [ 0.42754417]
#  [-0.72615063]
#  [ 0.02765137]]
# r(1,1,2) eigenvector:
# [[ 0.14486714]
#  [-0.39135051]
#  [ 0.33912377]
#  [ 0.42754417]
#  [-0.72615063]
#  [ 0.02765137]]
# r(1,2,1) eigenvector:
# [[-0.29350217]
#  [-0.61322284]
#  [-0.2373443 ]
#  [-0.41331311]
#  [-0.10311671]
#  [-0.54774185]]
# r(1,2,2) eigenvector:
# [[-0.29350217]
#  [-0.61322284]
#  [-0.2373443 ]
#  [-0.41331311]
#  [-0.10311671]
#  [-0.54774185]]
# r(2,1,1) eigenvector:
# [[-0.14486714]
#  [ 0.39135051]
#  [-0.33912377]
#  [-0.42754417]
#  [ 0.72615063]
#  [-0.02765137]]
# r(2,1,2) eigenvector:
# [[ 0.14486714]
#  [-0.39135051]
#  [ 0.33912377]
#  [ 0.42754417]
#  [-0.72615063]
#  [ 0.02765137]]
# r(2,2,1) eigenvector:
# [[-0.29350217]
#  [-0.61322284]
#  [-0.2373443 ]
#  [-0.41331311]
#  [-0.10311671]
#  [-0.54774185]]
# r(2,2,2) eigenvector:
# [[-0.29350217]
#  [-0.61322284]
#  [-0.2373443 ]
#  [-0.41331311]
#  [-0.10311671]
#  [-0.54774185]]
